# %% [markdown]
# # Problem 1: Visualize a static map (8 points)
#
# Create a static map using the skills you leared in lesson 5. The map should contain multiple layers of data (at least two different data sets), and you should pay attention to the classification and visualization (colors, edges etc.) when creating the map. Write your code into a notebook file (.ipynb) or a python script file (.py) and store the output map(s) in .png format into the docs folder.
#
# Topic of the map:
#
#     You can either use the data sets we have already used during this course (eg. the Travel Time Matrix, or population grid), or you can select some other data set of your interest (for example, statistics in postal code areas).
#     Feel free to adapt examples provided in this course! You can do further calculations based on the datasets or use the analysis outputs that we have done earlier in the course (for example, the dominance areas or travel times for shopping centers).
#
# Criteria:
#
#     The map should have multiple layers on it (for example, the travel time matrix and the road network). Basemap is optional (use a basemap only if it adds useful information / visual touch!)
#     The map should portray some kind of classification and/or an analysis output (not just the raw data).
#     Consider good cartographic practices (map extent, zoom level, color choices, legend, credit data sources etc.) when plotting the map.
#
# Output:
#
#     Remember to commit the code and input data (or at least a link to input data)
#     Save your map(s) as png image in the docs folder

# %% [markdown]
# In this exercise, I will use municipality polygons (2018), municipality-wise employment rates (2017), and population numbers (2018) provided by Statistics Finland. I will also use a text file containing the addresses for Finland's region center cities which I put together myself. The addresses for each city is the city's townhouse's address. I looked up the addresses from Google Maps.

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import json
import numpy as np
from pyproj import CRS

# %%
# Download the municipality polygons from year 2018

url = "http://geo.stat.fi/geoserver/tilastointialueet/wfs?request=GetFeature&typename=tilastointialueet:kunta1000k_2018&outputformat=JSON"
geokunnat = gpd.read_file(url)

# Read the municipality-wise employment rates (2017) and population numbers (2018)

kunnat = pd.read_excel(r"data/Kunnat_tyollisyys_vakiluku.xlsx")

# %%
kunnat.head()
# Out:
#   Unnamed: 0  Väkiluku, 2018  Työllisyysaste, %, 2017
# 0       Akaa           16611                     71.9
# 1   Alajärvi            9700                     67.7
# 2  Alavieska            2573                     71.5
# 3     Alavus           11544                     69.5
# 4   Asikkala            8149                     69.1

# %%
geokunnat.head()
# Out:
#                   id kunta  vuosi                                      nimi  \
# 0  kunta1000k_2018.1   005   2018  Alajärvi
# 1  kunta1000k_2018.2   009   2018  Alavieska
# 2  kunta1000k_2018.3   010   2018  Alavus
# 3  kunta1000k_2018.4   016   2018  Asikkala
# 4  kunta1000k_2018.5   018   2018  Askola
#
#                                        namn  \
# 0  Alajärvi
# 1  Alavieska
# 2  Alavus
# 3  Asikkala
# 4  Askola
#
#                                        name  \
# 0  Alajärvi
# 1  Alavieska
# 2  Alavus
# 3  Asikkala
# 4  Askola
#
#                                             geometry
# 0  MULTIPOLYGON (((347302.684 6959056.438, 348733...
# 1  MULTIPOLYGON (((370424.741 7104339.037, 371535...
# 2  MULTIPOLYGON (((319892.311 6920033.249, 319415...
# 3  MULTIPOLYGON (((434407.880 6774122.311, 438438...
# 4  MULTIPOLYGON (((423421.791 6704555.878, 425989...

# %%
# Drop the unnecessary columns from geokunnat and rename kunnat column "Unnamed: 0" to "nimi"; rename also other kunnat columns to be more simple

geokunnat = geokunnat[["nimi", "geometry"]]

kunnat = kunnat.rename(columns={"Unnamed: 0": "nimi", "Väkiluku, 2018": "pop18", "Työllisyysaste, %, 2017": "employment17"})

# %%
# Join these two layers

merged = geokunnat.merge(kunnat, on="nimi", how="left")

merged

# Hmmm, it seems that there's a problem that I didn't realize before since all values in the columns from kunnat become NaN.
# Out:
#                                          nimi  \
# 0    Alajärvi
# 1    Alavieska
# 2    Alavus
# 3    Asikkala
# 4    Askola
# ..                                        ...
# 306  Ylitornio
# 307  Ylivieska
# 308  Ylöjärvi
# 309  Ähtäri
# 310  Äänekoski
#
#                                               geometry  pop18  employment17
# 0    MULTIPOLYGON (((347302.684 6959056.438, 348733...    NaN           NaN
# 1    MULTIPOLYGON (((370424.741 7104339.037, 371535...    NaN           NaN
# 2    MULTIPOLYGON (((319892.311 6920033.249, 319415...    NaN           NaN
# 3    MULTIPOLYGON (((434407.880 6774122.311, 438438...    NaN           NaN
# 4    MULTIPOLYGON (((423421.791 6704555.878, 425989...    NaN           NaN
# ..                                                 ...    ...           ...
# 306  MULTIPOLYGON (((358732.539 7341893.208, 359611...    NaN           NaN
# 307  MULTIPOLYGON (((382933.310 7092789.500, 384323...    NaN           NaN
# 308  MULTIPOLYGON (((318400.367 6825031.514, 319504...    NaN           NaN
# 309  MULTIPOLYGON (((345455.367 6918226.112, 346809...    NaN           NaN
# 310  MULTIPOLYGON (((433727.949 6928362.717, 434429...    NaN           NaN
#
# [311 rows x 4 columns]

# %%
geokunnat_nimet = geokunnat["nimi"]

geokunnat_nimet.to_csv(r"data/nimet.csv")

# %%
kunnat["nimi"] == geokunnat["nimi"]

# And there's the problem: the municipalities in these two datasets don't match. 
# It seems that the municipalities in geokunnat aren't in an alphabetical order.
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 306    False
# 307    False
# 308    False
# 309    False
# 310    False
# Name: nimi, Length: 311, dtype: bool

# %%
# So, let's sort geokunnat according to nimi and see, what happens.

geokunnat = geokunnat.sort_values(by=["nimi"], ignore_index=True)

# I'll sort kunnat also, just to be sure.
kunnat = kunnat.sort_values(by=["nimi"], ignore_index=True)

geokunnat
# Out:
#                                          nimi  \
# 0    Akaa
# 1    Alajärvi
# 2    Alavieska
# 3    Alavus
# 4    Asikkala
# ..                                        ...
# 306  Ylivieska
# 307  Ylöjärvi
# 308  Ypäjä
# 309  Ähtäri
# 310  Äänekoski
#
#                                               geometry
# 0    MULTIPOLYGON (((324952.559 6773513.092, 327649...
# 1    MULTIPOLYGON (((347302.684 6959056.438, 348733...
# 2    MULTIPOLYGON (((370424.741 7104339.037, 371535...
# 3    MULTIPOLYGON (((319892.311 6920033.249, 319415...
# 4    MULTIPOLYGON (((434407.880 6774122.311, 438438...
# ..                                                 ...
# 306  MULTIPOLYGON (((382933.310 7092789.500, 384323...
# 307  MULTIPOLYGON (((318400.367 6825031.514, 319504...
# 308  MULTIPOLYGON (((296901.865 6736363.869, 297095...
# 309  MULTIPOLYGON (((345455.367 6918226.112, 346809...
# 310  MULTIPOLYGON (((433727.949 6928362.717, 434429...
#
# [311 rows x 2 columns]

# %%
kunnat["nimi"] == geokunnat["nimi"]

# Okey, so the names aren't the same now either. I really don't understand, why. There has to be something about the municipality names that I don't see.
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 306    False
# 307    False
# 308    False
# 309    False
# 310    False
# Name: nimi, Length: 311, dtype: bool

# %%
# I'll try to do the merge with "join" function, using index as the key.

geodata = geokunnat.join(kunnat, lsuffix='_caller', rsuffix='_other')

geodata

# Now it seems to be working fine and dandy!
# Out:
#                                   nimi_caller  \
# 0    Akaa
# 1    Alajärvi
# 2    Alavieska
# 3    Alavus
# 4    Asikkala
# ..                                        ...
# 306  Ylivieska
# 307  Ylöjärvi
# 308  Ypäjä
# 309  Ähtäri
# 310  Äänekoski
#
#                                               geometry nimi_other  pop18  \
# 0    MULTIPOLYGON (((324952.559 6773513.092, 327649...       Akaa  16611
# 1    MULTIPOLYGON (((347302.684 6959056.438, 348733...   Alajärvi   9700
# 2    MULTIPOLYGON (((370424.741 7104339.037, 371535...  Alavieska   2573
# 3    MULTIPOLYGON (((319892.311 6920033.249, 319415...     Alavus  11544
# 4    MULTIPOLYGON (((434407.880 6774122.311, 438438...   Asikkala   8149
# ..                                                 ...        ...    ...
# 306  MULTIPOLYGON (((382933.310 7092789.500, 384323...  Ylivieska  15212
# 307  MULTIPOLYGON (((318400.367 6825031.514, 319504...   Ylöjärvi  32983
# 308  MULTIPOLYGON (((296901.865 6736363.869, 297095...      Ypäjä   2357
# 309  MULTIPOLYGON (((345455.367 6918226.112, 346809...     Ähtäri   5703
# 310  MULTIPOLYGON (((433727.949 6928362.717, 434429...  Äänekoski  18851
#
#      employment17
# 0            71.9
# 1            67.7
# 2            71.5
# 3            69.5
# 4            69.1
# ..            ...
# 306          70.9
# 307          76.6
# 308          71.2
# 309          68.9
# 310          65.2
#
# [311 rows x 5 columns]

# %%
# Check the crs of geodata

print(geodata.crs)
# Out:
# epsg:3067

# %%
# Reproject

geodata = geodata.to_crs("EPSG:3879")

# %%
# Plot to see, how it looks

geodata.plot()
# Out:
# <AxesSubplot:>

# %%
# Let's once again check the data now that we have the municipality names from both datasets.

pd.set_option('display.max_rows', None)

geodata
# Out:
#                                   nimi_caller  \
# 0    Akaa
# 1    Alajärvi
# 2    Alavieska
# 3    Alavus
# 4    Asikkala
# 5    Askola
# 6    Aura
# 7    Brändö
# 8    Eckerö
# 9    Enonkoski
# 10   Enontekiö
# 11   Espoo
# 12   Eura
# 13   Eurajoki
# 14   Evijärvi
# 15   Finström
# 16   Forssa
# 17   Föglö
# 18   Geta
# 19   Haapajärvi
# 20   Haapavesi
# 21   Hailuoto
# 22   Halsua
# 23   Hamina
# 24   Hammarland
# 25   Hankasalmi
# 26   Hanko
# 27   Harjavalta
# 28   Hartola
# 29   Hattula
# 30   Hausjärvi
# 31   Heinola
# 32   Heinävesi
# 33   Helsinki
# 34   Hirvensalmi
# 35   Hollola
# 36   Honkajoki
# 37   Huittinen
# 38   Humppila
# 39   Hyrynsalmi
# 40   Hyvinkää
# 41   Hämeenkyrö
# 42   Hämeenlinna
# 43   Ii
# 44   Iisalmi
# 45   Iitti
# 46   Ikaalinen
# 47   Ilmajoki
# 48   Ilomantsi
# 49   Imatra
# 50   Inari
# 51   Inkoo
# 52   Isojoki
# 53   Isokyrö
# 54   Janakkala
# 55   Joensuu
# 56   Jokioinen
# 57   Jomala
# 58   Joroinen
# 59   Joutsa
# 60   Juuka
# 61   Juupajoki
# 62   Juva
# 63   Jyväskylä
# 64   Jämijärvi
# 65   Jämsä
# 66   Järvenpää
# 67   Kaarina
# 68   Kaavi
# 69   Kajaani
# 70   Kalajoki
# 71   Kangasala
# 72   Kangasniemi
# 73   Kankaanpää
# 74   Kannonkoski
# 75   Kannus
# 76   Karijoki
# 77   Karkkila
# 78   Karstula
# 79   Karvia
# 80   Kaskinen
# 81   Kauhajoki
# 82   Kauhava
# 83   Kauniainen
# 84   Kaustinen
# 85   Keitele
# 86   Kemi
# 87   Kemijärvi
# 88   Keminmaa
# 89   Kemiönsaari
# 90   Kempele
# 91   Kerava
# 92   Keuruu
# 93   Kihniö
# 94   Kinnula
# 95   Kirkkonummi
# 96   Kitee
# 97   Kittilä
# 98   Kiuruvesi
# 99   Kivijärvi
# 100  Kokemäki
# 101  Kokkola
# 102  Kolari
# 103  Konnevesi
# 104  Kontiolahti
# 105  Korsnäs
# 106  Koski Tl
# 107  Kotka
# 108  Kouvola
# 109  Kristiinankaupunki
# 110  Kruunupyy
# 111  Kuhmo
# 112  Kuhmoinen
# 113  Kumlinge
# 114  Kuopio
# 115  Kuortane
# 116  Kurikka
# 117  Kustavi
# 118  Kuusamo
# 119  Kyyjärvi
# 120  Kärkölä
# 121  Kärsämäki
# 122  Kökar
# 123  Lahti
# 124  Laihia
# 125  Laitila
# 126  Lapinjärvi
# 127  Lapinlahti
# 128  Lappajärvi
# 129  Lappeenranta
# 130  Lapua
# 131  Laukaa
# 132  Lemi
# 133  Lemland
# 134  Lempäälä
# 135  Leppävirta
# 136  Lestijärvi
# 137  Lieksa
# 138  Lieto
# 139  Liminka
# 140  Liperi
# 141  Lohja
# 142  Loimaa
# 143  Loppi
# 144  Loviisa
# 145  Luhanka
# 146  Lumijoki
# 147  Lumparland
# 148  Luoto
# 149  Luumäki
# 150  Maalahti
# 151  Maarianhamina - Mariehamn
# 152  Marttila
# 153  Masku
# 154  Merijärvi
# 155  Merikarvia
# 156  Miehikkälä
# 157  Mikkeli
# 158  Muhos
# 159  Multia
# 160  Muonio
# 161  Mustasaari
# 162  Muurame
# 163  Mynämäki
# 164  Myrskylä
# 165  Mäntsälä
# 166  Mänttä-Vilppula
# 167  Mäntyharju
# 168  Naantali
# 169  Nakkila
# 170  Nivala
# 171  Nokia
# 172  Nousiainen
# 173  Nurmes
# 174  Nurmijärvi
# 175  Närpiö
# 176  Orimattila
# 177  Oripää
# 178  Orivesi
# 179  Oulainen
# 180  Oulu
# 181  Outokumpu
# 182  Padasjoki
# 183  Paimio
# 184  Paltamo
# 185  Parainen
# 186  Parikkala
# 187  Parkano
# 188  Pedersören kunta
# 189  Pelkosenniemi
# 190  Pello
# 191  Perho
# 192  Pertunmaa
# 193  Petäjävesi
# 194  Pieksämäki
# 195  Pielavesi
# 196  Pietarsaari
# 197  Pihtipudas
# 198  Pirkkala
# 199  Polvijärvi
# 200  Pomarkku
# 201  Pori
# 202  Pornainen
# 203  Porvoo
# 204  Posio
# 205  Pudasjärvi
# 206  Pukkila
# 207  Punkalaidun
# 208  Puolanka
# 209  Puumala
# 210  Pyhtää
# 211  Pyhäjoki
# 212  Pyhäjärvi
# 213  Pyhäntä
# 214  Pyhäranta
# 215  Pälkäne
# 216  Pöytyä
# 217  Raahe
# 218  Raasepori
# 219  Raisio
# 220  Rantasalmi
# 221  Ranua
# 222  Rauma
# 223  Rautalampi
# 224  Rautavaara
# 225  Rautjärvi
# 226  Reisjärvi
# 227  Riihimäki
# 228  Ristijärvi
# 229  Rovaniemi
# 230  Ruokolahti
# 231  Ruovesi
# 232  Rusko
# 233  Rääkkylä
# 234  Saarijärvi
# 235  Salla
# 236  Salo
# 237  Saltvik
# 238  Sastamala
# 239  Sauvo
# 240  Savitaipale
# 241  Savonlinna
# 242  Savukoski
# 243  Seinäjoki
# 244  Sievi
# 245  Siikainen
# 246  Siikajoki
# 247  Siikalatva
# 248  Siilinjärvi
# 249  Simo
# 250  Sipoo
# 251  Siuntio
# 252  Sodankylä
# 253  Soini
# 254  Somero
# 255  Sonkajärvi
# 256  Sotkamo
# 257  Sottunga
# 258  Sulkava
# 259  Sund
# 260  Suomussalmi
# 261  Suonenjoki
# 262  Sysmä
# 263  Säkylä
# 264  Taipalsaari
# 265  Taivalkoski
# 266  Taivassalo
# 267  Tammela
# 268  Tampere
# 269  Tervo
# 270  Tervola
# 271  Teuva
# 272  Tohmajärvi
# 273  Toholampi
# 274  Toivakka
# 275  Tornio
# 276  Turku
# 277  Tuusniemi
# 278  Tuusula
# 279  Tyrnävä
# 280  Ulvila
# 281  Urjala
# 282  Utajärvi
# 283  Utsjoki
# 284  Uurainen
# 285  Uusikaarlepyy
# 286  Uusikaupunki
# 287  Vaala
# 288  Vaasa
# 289  Valkeakoski
# 290  Valtimo
# 291  Vantaa
# 292  Varkaus
# 293  Vehmaa
# 294  Vesanto
# 295  Vesilahti
# 296  Veteli
# 297  Vieremä
# 298  Vihti
# 299  Viitasaari
# 300  Vimpeli
# 301  Virolahti
# 302  Virrat
# 303  Vårdö
# 304  Vöyri
# 305  Ylitornio
# 306  Ylivieska
# 307  Ylöjärvi
# 308  Ypäjä
# 309  Ähtäri
# 310  Äänekoski
#
#                                               geometry          nimi_other  \
# 0    MULTIPOLYGON (((25432855.364 6772522.137, 2543...                Akaa
# 1    MULTIPOLYGON (((25449483.076 6958686.809, 2545...            Alajärvi
# 2    MULTIPOLYGON (((25468062.983 7104646.044, 2546...           Alavieska
# 3    MULTIPOLYGON (((25423291.995 6918828.726, 2542...              Alavus
# 4    MULTIPOLYGON (((25542265.535 6776476.194, 2554...            Asikkala
# 5    MULTIPOLYGON (((25533400.510 6706582.537, 2553...              Askola
# 6    MULTIPOLYGON (((25366506.122 6719591.569, 2536...                Aura
# 7    MULTIPOLYGON (((25280223.667 6732167.929, 2528...              Brändö
# 8    MULTIPOLYGON (((25202411.338 6707350.762, 2520...              Eckerö
# 9    MULTIPOLYGON (((25705112.555 6882690.638, 2570...           Enonkoski
# 10   MULTIPOLYGON (((25456844.431 7559175.865, 2546...           Enontekiö
# 11   MULTIPOLYGON (((25490916.172 6672216.944, 2549...               Espoo
# 12   MULTIPOLYGON (((25345767.105 6754571.087, 2534...                Eura
# 13   MULTIPOLYGON (((25305163.668 6823427.488, 2530...            Eurajoki
# 14   MULTIPOLYGON (((25423728.987 7020564.483, 2542...            Evijärvi
# 15   MULTIPOLYGON (((25217375.056 6699895.969, 2521...            Finström
# 16   MULTIPOLYGON (((25425610.767 6741700.492, 2542...              Forssa
# 17   MULTIPOLYGON (((25251704.034 6677357.898, 2525...               Föglö
# 18   MULTIPOLYGON (((25211592.111 6713484.903, 2521...                Geta
# 19   MULTIPOLYGON (((25517284.607 7053246.993, 2552...          Haapajärvi
# 20   MULTIPOLYGON (((25526204.554 7091224.298, 2552...           Haapavesi
# 21   MULTIPOLYGON (((25490186.078 7204851.231, 2549...            Hailuoto
# 22   MULTIPOLYGON (((25458151.593 7025654.162, 2546...              Halsua
# 23   MULTIPOLYGON (((25619307.318 6718692.685, 2561...              Hamina
# 24   MULTIPOLYGON (((25202779.455 6712521.870, 2520...          Hammarland
# 25   MULTIPOLYGON (((25569253.365 6899133.262, 2557...          Hankasalmi
# 26   MULTIPOLYGON (((25395095.029 6647417.783, 2539...               Hanko
# 27   MULTIPOLYGON (((25346038.829 6798417.977, 2534...          Harjavalta
# 28   MULTIPOLYGON (((25562677.682 6809837.903, 2556...             Hartola
# 29   MULTIPOLYGON (((25450337.194 6749953.344, 2545...             Hattula
# 30   MULTIPOLYGON (((25506149.649 6727791.732, 2550...           Hausjärvi
# 31   MULTIPOLYGON (((25550575.573 6773757.984, 2555...             Heinola
# 32   MULTIPOLYGON (((25696635.794 6905509.646, 2569...           Heinävesi
# 33   MULTIPOLYGON (((25512356.535 6681440.248, 2551...            Helsinki
# 34   MULTIPOLYGON (((25604552.973 6823166.817, 2560...         Hirvensalmi
# 35   MULTIPOLYGON (((25521862.480 6749332.083, 2552...             Hollola
# 36   MULTIPOLYGON (((25349571.131 6868685.490, 2534...           Honkajoki
# 37   MULTIPOLYGON (((25376010.121 6765721.011, 2537...           Huittinen
# 38   MULTIPOLYGON (((25414274.808 6752159.047, 2541...            Humppila
# 39   MULTIPOLYGON (((25695324.328 7156636.725, 2570...          Hyrynsalmi
# 40   MULTIPOLYGON (((25481505.546 6710733.956, 2548...            Hyvinkää
# 41   MULTIPOLYGON (((25413869.343 6824386.151, 2541...          Hämeenkyrö
# 42   MULTIPOLYGON (((25467189.683 6738230.566, 2546...         Hämeenlinna
# 43   MULTIPOLYGON (((25515274.028 7262854.404, 2551...                  Ii
# 44   MULTIPOLYGON (((25602926.526 7023391.455, 2560...             Iisalmi
# 45   MULTIPOLYGON (((25567033.242 6738023.940, 2556...               Iitti
# 46   MULTIPOLYGON (((25384788.100 6842653.611, 2538...           Ikaalinen
# 47   MULTIPOLYGON (((25380923.773 6945618.879, 2538...            Ilmajoki
# 48   MULTIPOLYGON (((25807794.340 6934025.650, 2581...           Ilomantsi
# 49   MULTIPOLYGON (((25703757.015 6780205.886, 2570...              Imatra
# 50   MULTIPOLYGON (((25540311.224 7577161.173, 2554...               Inari
# 51   MULTIPOLYGON (((25455375.273 6658852.606, 2545...               Inkoo
# 52   MULTIPOLYGON (((25341414.894 6878372.472, 2534...             Isojoki
# 53   MULTIPOLYGON (((25360903.635 6968048.972, 2536...             Isokyrö
# 54   MULTIPOLYGON (((25472229.643 6737139.328, 2547...           Janakkala
# 55   MULTIPOLYGON (((25800556.078 6918336.601, 2580...             Joensuu
# 56   MULTIPOLYGON (((25413196.985 6737549.097, 2541...           Jokioinen
# 57   MULTIPOLYGON (((25211155.536 6676562.146, 2521...              Jomala
# 58   MULTIPOLYGON (((25646406.465 6878718.706, 2564...            Joroinen
# 59   MULTIPOLYGON (((25569785.054 6834000.155, 2557...              Joutsa
# 60   MULTIPOLYGON (((25733486.192 6993237.608, 2573...               Juuka
# 61   MULTIPOLYGON (((25476486.589 6845309.915, 2547...           Juupajoki
# 62   MULTIPOLYGON (((25654197.579 6829723.666, 2565...                Juva
# 63   MULTIPOLYGON (((25531414.762 6859190.372, 2553...           Jyväskylä
# 64   MULTIPOLYGON (((25379464.815 6849666.992, 2538...           Jämijärvi
# 65   MULTIPOLYGON (((25497896.479 6835770.547, 2549...               Jämsä
# 66   MULTIPOLYGON (((25505384.571 6703549.690, 2550...           Järvenpää
# 67   MULTIPOLYGON (((25360900.287 6698943.381, 2536...             Kaarina
# 68   MULTIPOLYGON (((25700613.242 6969386.618, 2570...               Kaavi
# 69   MULTIPOLYGON (((25643946.566 7085827.922, 2564...             Kajaani
# 70   MULTIPOLYGON (((25428110.122 7135706.910, 2542...            Kalajoki
# 71   MULTIPOLYGON (((25447683.119 6801080.355, 2544...           Kangasala
# 72   MULTIPOLYGON (((25586816.151 6854477.041, 2558...         Kangasniemi
# 73   MULTIPOLYGON (((25370653.487 6844374.267, 2537...          Kankaanpää
# 74   MULTIPOLYGON (((25515316.852 6968186.240, 2552...         Kannonkoski
# 75   MULTIPOLYGON (((25449914.255 7073080.385, 2545...              Kannus
# 76   MULTIPOLYGON (((25331911.188 6905945.177, 2533...            Karijoki
# 77   MULTIPOLYGON (((25460846.089 6707259.112, 2546...            Karkkila
# 78   MULTIPOLYGON (((25474630.044 6956206.880, 2547...            Karstula
# 79   MULTIPOLYGON (((25370202.899 6879198.013, 2537...              Karvia
# 80   MULTIPOLYGON (((25306369.294 6922488.449, 2530...            Kaskinen
# 81   MULTIPOLYGON (((25360079.522 6891314.466, 2536...           Kauhajoki
# 82   MULTIPOLYGON (((25416646.529 6992495.316, 2541...             Kauhava
# 83   MULTIPOLYGON (((25484592.324 6676673.558, 2548...          Kauniainen
# 84   MULTIPOLYGON (((25433115.095 7042920.432, 2543...           Kaustinen
# 85   MULTIPOLYGON (((25576792.560 6988379.086, 2557...             Keitele
# 86   MULTIPOLYGON (((25473386.212 7293363.095, 2547...                Kemi
# 87   MULTIPOLYGON (((25608373.022 7357164.249, 2561...           Kemijärvi
# 88   MULTIPOLYGON (((25488394.553 7288857.560, 2549...            Keminmaa
# 89   MULTIPOLYGON (((25379591.863 6684276.541, 2537...         Kemiönsaari
# 90   MULTIPOLYGON (((25528722.347 7193913.857, 2552...             Kempele
# 91   MULTIPOLYGON (((25508374.620 6694111.743, 2550...              Kerava
# 92   MULTIPOLYGON (((25485911.086 6879544.760, 2549...              Keuruu
# 93   MULTIPOLYGON (((25410922.231 6887345.850, 2541...              Kihniö
# 94   MULTIPOLYGON (((25499254.263 7014195.115, 2550...             Kinnula
# 95   MULTIPOLYGON (((25479812.649 6668324.522, 2548...         Kirkkonummi
# 96   MULTIPOLYGON (((25740930.876 6854406.228, 2576...               Kitee
# 97   MULTIPOLYGON (((25515172.720 7451268.697, 2552...             Kittilä
# 98   MULTIPOLYGON (((25575102.760 7037378.702, 2557...           Kiuruvesi
# 99   MULTIPOLYGON (((25502658.929 6989264.902, 2550...           Kivijärvi
# 100  MULTIPOLYGON (((25364422.878 6787118.420, 2536...            Kokemäki
# 101  MULTIPOLYGON (((25422391.594 7110664.394, 2542...             Kokkola
# 102  MULTIPOLYGON (((25494323.979 7427431.735, 2549...              Kolari
# 103  MULTIPOLYGON (((25560712.007 6930814.160, 2556...           Konnevesi
# 104  MULTIPOLYGON (((25754007.991 6949772.363, 2575...         Kontiolahti
# 105  MULTIPOLYGON (((25301306.386 6985177.426, 2530...             Korsnäs
# 106  MULTIPOLYGON (((25400795.609 6719074.685, 2540...            Koski Tl
# 107  MULTIPOLYGON (((25611081.841 6710740.757, 2561...               Kotka
# 108  MULTIPOLYGON (((25584528.976 6719129.082, 2558...             Kouvola
# 109  MULTIPOLYGON (((25310813.760 6915716.830, 2531...  Kristiinankaupunki
# 110  MULTIPOLYGON (((25434836.557 7031439.354, 2543...           Kruunupyy
# 111  MULTIPOLYGON (((25735990.755 7075610.147, 2574...               Kuhmo
# 112  MULTIPOLYGON (((25498425.459 6815717.114, 2550...           Kuhmoinen
# 113  MULTIPOLYGON (((25261731.586 6711601.031, 2526...            Kumlinge
# 114  MULTIPOLYGON (((25671702.960 6947457.047, 2567...              Kuopio
# 115  MULTIPOLYGON (((25425557.786 6950343.086, 2542...            Kuortane
# 116  MULTIPOLYGON (((25390786.399 6908685.500, 2539...             Kurikka
# 117  MULTIPOLYGON (((25282620.304 6740338.301, 2528...             Kustavi
# 118  MULTIPOLYGON (((25708494.045 7273214.317, 2570...             Kuusamo
# 119  MULTIPOLYGON (((25473716.176 6980823.458, 2547...            Kyyjärvi
# 120  MULTIPOLYGON (((25516255.978 6737891.537, 2551...             Kärkölä
# 121  MULTIPOLYGON (((25533223.795 7076271.137, 2553...           Kärsämäki
# 122  MULTIPOLYGON (((25268727.553 6665249.574, 2526...               Kökar
# 123  MULTIPOLYGON (((25549881.640 6753212.432, 2555...               Lahti
# 124  MULTIPOLYGON (((25356979.413 6963802.086, 2536...              Laihia
# 125  MULTIPOLYGON (((25325417.433 6740607.623, 2532...             Laitila
# 126  MULTIPOLYGON (((25570684.955 6710427.420, 2557...          Lapinjärvi
# 127  MULTIPOLYGON (((25628281.167 7008066.351, 2562...          Lapinlahti
# 128  MULTIPOLYGON (((25423980.332 6986934.111, 2542...          Lappajärvi
# 129  MULTIPOLYGON (((25661327.799 6732029.554, 2566...        Lappeenranta
# 130  MULTIPOLYGON (((25412124.372 6964447.440, 2541...               Lapua
# 131  MULTIPOLYGON (((25554617.502 6897575.933, 2555...              Laukaa
# 132  MULTIPOLYGON (((25654611.732 6768170.336, 2565...                Lemi
# 133  MULTIPOLYGON (((25225095.855 6675681.668, 2522...             Lemland
# 134  MULTIPOLYGON (((25436159.837 6791782.446, 2543...            Lempäälä
# 135  MULTIPOLYGON (((25658856.480 6912407.367, 2565...          Leppävirta
# 136  MULTIPOLYGON (((25488634.690 7028385.245, 2549...          Lestijärvi
# 137  MULTIPOLYGON (((25771458.200 6999534.432, 2577...              Lieksa
# 138  MULTIPOLYGON (((25356779.799 6706713.846, 2535...               Lieto
# 139  MULTIPOLYGON (((25558544.717 7151995.244, 2556...             Liminka
# 140  MULTIPOLYGON (((25740391.779 6925664.384, 2574...              Liperi
# 141  MULTIPOLYGON (((25441217.138 6668970.506, 2544...               Lohja
# 142  MULTIPOLYGON (((25392505.141 6733543.068, 2539...              Loimaa
# 143  MULTIPOLYGON (((25468379.349 6715768.230, 2547...               Loppi
# 144  MULTIPOLYGON (((25554043.137 6706302.418, 2555...             Loviisa
# 145  MULTIPOLYGON (((25530028.111 6840685.699, 2553...             Luhanka
# 146  MULTIPOLYGON (((25513045.439 7197726.697, 2551...            Lumijoki
# 147  MULTIPOLYGON (((25236474.331 6680709.232, 2523...          Lumparland
# 148  MULTIPOLYGON (((25390736.453 7092215.205, 2539...               Luoto
# 149  MULTIPOLYGON (((25647756.306 6745743.225, 2564...             Luumäki
# 150  MULTIPOLYGON (((25284786.867 7008884.970, 2528...            Maalahti
# 151  MULTIPOLYGON (((25219340.233 6671574.757, 2521...       Maarianhamina
# 152  MULTIPOLYGON (((25381679.382 6712929.965, 2538...            Marttila
# 153  MULTIPOLYGON (((25329678.666 6716391.022, 2532...               Masku
# 154  MULTIPOLYGON (((25479685.666 7120706.378, 2548...           Merijärvi
# 155  MULTIPOLYGON (((25308850.603 6874547.079, 2530...          Merikarvia
# 156  MULTIPOLYGON (((25636633.791 6723635.560, 2563...          Miehikkälä
# 157  MULTIPOLYGON (((25627190.722 6791080.232, 2562...             Mikkeli
# 158  MULTIPOLYGON (((25562088.899 7153891.976, 2556...               Muhos
# 159  MULTIPOLYGON (((25494930.450 6912134.493, 2550...              Multia
# 160  MULTIPOLYGON (((25436216.571 7484944.396, 2543...              Muonio
# 161  MULTIPOLYGON (((25304458.798 7042830.221, 2530...          Mustasaari
# 162  MULTIPOLYGON (((25540156.757 6884251.559, 2554...             Muurame
# 163  MULTIPOLYGON (((25328864.874 6722759.891, 2532...            Mynämäki
# 164  MULTIPOLYGON (((25545308.329 6715496.080, 2554...            Myrskylä
# 165  MULTIPOLYGON (((25512319.787 6709983.796, 2551...            Mäntsälä
# 166  MULTIPOLYGON (((25468869.757 6866603.629, 2547...     Mänttä-Vilppula
# 167  MULTIPOLYGON (((25609363.358 6784135.990, 2561...          Mäntyharju
# 168  MULTIPOLYGON (((25318683.227 6714195.262, 2531...            Naantali
# 169  MULTIPOLYGON (((25339785.887 6801751.820, 2534...             Nakkila
# 170  MULTIPOLYGON (((25506511.133 7074090.719, 2550...              Nivala
# 171  MULTIPOLYGON (((25415514.985 6803023.309, 2541...               Nokia
# 172  MULTIPOLYGON (((25337718.640 6720588.916, 2533...          Nousiainen
# 173  MULTIPOLYGON (((25723536.806 7034951.543, 2572...              Nurmes
# 174  MULTIPOLYGON (((25486154.579 6692178.993, 2549...          Nurmijärvi
# 175  MULTIPOLYGON (((25298937.821 6956423.551, 2529...              Närpiö
# 176  MULTIPOLYGON (((25533393.030 6729042.538, 2553...          Orimattila
# 177  MULTIPOLYGON (((25381204.072 6746660.154, 2537...              Oripää
# 178  MULTIPOLYGON (((25480072.161 6822798.767, 2548...             Orivesi
# 179  MULTIPOLYGON (((25495436.635 7112058.839, 2549...            Oulainen
# 180  MULTIPOLYGON (((25508833.970 7227616.722, 2550...                Oulu
# 181  MULTIPOLYGON (((25704548.928 6946787.302, 2570...           Outokumpu
# 182  MULTIPOLYGON (((25510039.499 6792247.471, 2551...           Padasjoki
# 183  MULTIPOLYGON (((25369571.991 6697004.232, 2537...              Paimio
# 184  MULTIPOLYGON (((25617491.564 7134748.035, 2562...             Paltamo
# 185  MULTIPOLYGON (((25300734.968 6710837.411, 2530...            Parainen
# 186  MULTIPOLYGON (((25737125.498 6820876.067, 2573...           Parikkala
# 187  MULTIPOLYGON (((25402713.024 6866793.603, 2540...             Parkano
# 188  MULTIPOLYGON (((25405526.601 7028487.047, 2541...    Pedersören kunta
# 189  MULTIPOLYGON (((25626247.095 7424551.054, 2562...       Pelkosenniemi
# 190  MULTIPOLYGON (((25452991.360 7375135.329, 2545...               Pello
# 191  MULTIPOLYGON (((25467648.933 7001523.510, 2547...               Perho
# 192  MULTIPOLYGON (((25580618.051 6804291.592, 2558...           Pertunmaa
# 193  MULTIPOLYGON (((25514869.920 6893943.922, 2551...          Petäjävesi
# 194  MULTIPOLYGON (((25625316.342 6879894.957, 2562...          Pieksämäki
# 195  MULTIPOLYGON (((25581299.663 6994090.110, 2558...           Pielavesi
# 196  MULTIPOLYGON (((25380162.386 7069859.665, 2538...         Pietarsaari
# 197  MULTIPOLYGON (((25532523.676 7015927.515, 2553...          Pihtipudas
# 198  MULTIPOLYGON (((25421811.229 6806133.199, 2542...            Pirkkala
# 199  MULTIPOLYGON (((25725203.435 6960498.858, 2572...          Polvijärvi
# 200  MULTIPOLYGON (((25342685.796 6837609.745, 2534...            Pomarkku
# 201  MULTIPOLYGON (((25314681.844 6848878.175, 2531...                Pori
# 202  MULTIPOLYGON (((25520030.869 6699373.755, 2552...           Pornainen
# 203  MULTIPOLYGON (((25537402.384 6696290.807, 2553...              Porvoo
# 204  MULTIPOLYGON (((25647452.325 7304389.039, 2565...               Posio
# 205  MULTIPOLYGON (((25615318.034 7223299.897, 2562...          Pudasjärvi
# 206  MULTIPOLYGON (((25528299.740 6718790.232, 2552...             Pukkila
# 207  MULTIPOLYGON (((25402368.098 6766974.417, 2540...         Punkalaidun
# 208  MULTIPOLYGON (((25621770.919 7158315.237, 2562...            Puolanka
# 209  MULTIPOLYGON (((25656810.480 6808059.654, 2565...             Puumala
# 210  MULTIPOLYGON (((25597313.444 6706130.174, 2559...              Pyhtää
# 211  MULTIPOLYGON (((25467292.029 7133496.103, 2546...            Pyhäjoki
# 212  MULTIPOLYGON (((25549655.965 7036601.974, 2555...           Pyhäjärvi
# 213  MULTIPOLYGON (((25561186.088 7082729.319, 2556...             Pyhäntä
# 214  MULTIPOLYGON (((25301259.168 6771372.872, 2530...           Pyhäranta
# 215  MULTIPOLYGON (((25462531.376 6791681.014, 2546...             Pälkäne
# 216  MULTIPOLYGON (((25381779.389 6725845.772, 2538...              Pöytyä
# 217  MULTIPOLYGON (((25472975.408 7177175.742, 2547...               Raahe
# 218  MULTIPOLYGON (((25417813.967 6663934.250, 2541...           Raasepori
# 219  MULTIPOLYGON (((25340717.779 6707585.959, 2534...              Raisio
# 220  MULTIPOLYGON (((25680224.089 6872092.106, 2568...          Rantasalmi
# 221  MULTIPOLYGON (((25583809.218 7290731.738, 2559...               Ranua
# 222  MULTIPOLYGON (((25307764.142 6796622.827, 2530...               Rauma
# 223  MULTIPOLYGON (((25590962.709 6925424.130, 2559...          Rautalampi
# 224  MULTIPOLYGON (((25681621.317 7016215.478, 2568...          Rautavaara
# 225  MULTIPOLYGON (((25719426.076 6795800.805, 2572...           Rautjärvi
# 226  MULTIPOLYGON (((25501811.318 7039444.338, 2550...           Reisjärvi
# 227  MULTIPOLYGON (((25485769.909 6726243.580, 2548...           Riihimäki
# 228  MULTIPOLYGON (((25678763.809 7139314.413, 2568...          Ristijärvi
# 229  MULTIPOLYGON (((25549056.483 7340593.163, 2554...           Rovaniemi
# 230  MULTIPOLYGON (((25716232.567 6793150.954, 2571...          Ruokolahti
# 231  MULTIPOLYGON (((25447232.047 6853617.160, 2545...             Ruovesi
# 232  MULTIPOLYGON (((25348697.354 6713506.514, 2534...               Rusko
# 233  MULTIPOLYGON (((25758019.470 6903081.091, 2575...            Rääkkylä
# 234  MULTIPOLYGON (((25520913.211 6935042.643, 2552...          Saarijärvi
# 235  MULTIPOLYGON (((25643932.831 7373147.513, 2564...               Salla
# 236  MULTIPOLYGON (((25393117.053 6695917.043, 2539...                Salo
# 237  MULTIPOLYGON (((25237249.400 6723233.149, 2523...             Saltvik
# 238  MULTIPOLYGON (((25392723.052 6787806.211, 2539...           Sastamala
# 239  MULTIPOLYGON (((25381368.584 6685674.067, 2538...               Sauvo
# 240  MULTIPOLYGON (((25639104.882 6770197.636, 2563...         Savitaipale
# 241  MULTIPOLYGON (((25715298.790 6831657.181, 2572...          Savonlinna
# 242  MULTIPOLYGON (((25645845.907 7450351.777, 2565...           Savukoski
# 243  MULTIPOLYGON (((25403804.257 6913884.463, 2540...           Seinäjoki
# 244  MULTIPOLYGON (((25481110.671 7060993.295, 2548...               Sievi
# 245  MULTIPOLYGON (((25343649.215 6852260.222, 2534...           Siikainen
# 246  MULTIPOLYGON (((25521095.214 7146148.054, 2552...           Siikajoki
# 247  MULTIPOLYGON (((25558178.837 7099851.262, 2555...          Siikalatva
# 248  MULTIPOLYGON (((25643703.742 6986184.051, 2564...         Siilinjärvi
# 249  MULTIPOLYGON (((25492807.262 7282833.045, 2549...                Simo
# 250  MULTIPOLYGON (((25520638.957 6683279.703, 2552...               Sipoo
# 251  MULTIPOLYGON (((25463684.953 6661045.143, 2546...             Siuntio
# 252  MULTIPOLYGON (((25566363.641 7428797.619, 2557...           Sodankylä
# 253  MULTIPOLYGON (((25472970.370 6952332.433, 2547...               Soini
# 254  MULTIPOLYGON (((25425333.204 6706910.151, 2542...              Somero
# 255  MULTIPOLYGON (((25630706.266 7047073.145, 2563...          Sonkajärvi
# 256  MULTIPOLYGON (((25662038.258 7067085.664, 2566...             Sotkamo
# 257  MULTIPOLYGON (((25254244.689 6682528.855, 2525...            Sottunga
# 258  MULTIPOLYGON (((25706719.540 6830419.901, 2571...             Sulkava
# 259  MULTIPOLYGON (((25233836.810 6696236.666, 2523...                Sund
# 260  MULTIPOLYGON (((25713645.725 7170498.877, 2571...         Suomussalmi
# 261  MULTIPOLYGON (((25600754.120 6927783.604, 2560...          Suonenjoki
# 262  MULTIPOLYGON (((25543258.026 6800683.618, 2554...               Sysmä
# 263  MULTIPOLYGON (((25354263.793 6759122.257, 2535...              Säkylä
# 264  MULTIPOLYGON (((25661489.346 6776039.780, 2566...         Taipalsaari
# 265  MULTIPOLYGON (((25647740.552 7242955.571, 2565...         Taivalkoski
# 266  MULTIPOLYGON (((25302742.908 6728435.620, 2530...          Taivassalo
# 267  MULTIPOLYGON (((25443710.728 6725620.109, 2544...             Tammela
# 268  MULTIPOLYGON (((25440761.572 6813620.217, 2544...             Tampere
# 269  MULTIPOLYGON (((25591993.665 6966965.510, 2559...               Tervo
# 270  MULTIPOLYGON (((25503714.605 7316573.824, 2550...             Tervola
# 271  MULTIPOLYGON (((25338279.398 6921171.375, 2534...               Teuva
# 272  MULTIPOLYGON (((25785567.018 6895781.996, 2578...          Tohmajärvi
# 273  MULTIPOLYGON (((25470611.444 7051610.757, 2547...           Toholampi
# 274  MULTIPOLYGON (((25558486.025 6877054.572, 2556...            Toivakka
# 275  MULTIPOLYGON (((25467205.804 7298312.506, 2546...              Tornio
# 276  MULTIPOLYGON (((25342432.152 6703315.649, 2534...               Turku
# 277  MULTIPOLYGON (((25683820.941 6946679.036, 2568...           Tuusniemi
# 278  MULTIPOLYGON (((25497491.670 6691113.515, 2549...             Tuusula
# 279  MULTIPOLYGON (((25551076.379 7163018.587, 2555...             Tyrnävä
# 280  MULTIPOLYGON (((25329202.833 6812594.942, 2533...              Ulvila
# 281  MULTIPOLYGON (((25437084.515 6759332.091, 2543...              Urjala
# 282  MULTIPOLYGON (((25574154.588 7162986.085, 2557...            Utajärvi
# 283  MULTIPOLYGON (((25529343.755 7674064.380, 2558...             Utsjoki
# 284  MULTIPOLYGON (((25526127.486 6919182.372, 2552...            Uurainen
# 285  MULTIPOLYGON (((25372035.123 7062284.502, 2537...       Uusikaarlepyy
# 286  MULTIPOLYGON (((25299501.217 6771702.423, 2529...        Uusikaupunki
# 287  MULTIPOLYGON (((25585657.840 7130604.897, 2558...               Vaala
# 288  MULTIPOLYGON (((25322301.287 7008643.082, 2532...               Vaasa
# 289  MULTIPOLYGON (((25443817.719 6777298.699, 2544...         Valkeakoski
# 290  MULTIPOLYGON (((25681833.981 7055795.052, 2568...             Valtimo
# 291  MULTIPOLYGON (((25507525.760 6680511.180, 2550...              Vantaa
# 292  MULTIPOLYGON (((25688534.927 6897908.371, 2568...             Varkaus
# 293  MULTIPOLYGON (((25321095.318 6724303.839, 2532...              Vehmaa
# 294  MULTIPOLYGON (((25569309.829 6960960.226, 2557...             Vesanto
# 295  MULTIPOLYGON (((25423073.801 6788576.515, 2542...           Vesilahti
# 296  MULTIPOLYGON (((25452389.531 7017510.111, 2545...              Veteli
# 297  MULTIPOLYGON (((25596795.611 7057912.082, 2559...             Vieremä
# 298  MULTIPOLYGON (((25463584.056 6681684.247, 2546...               Vihti
# 299  MULTIPOLYGON (((25550266.376 6974091.647, 2555...          Viitasaari
# 300  MULTIPOLYGON (((25436845.092 6997412.420, 2544...             Vimpeli
# 301  MULTIPOLYGON (((25651237.878 6720488.580, 2565...           Virolahti
# 302  MULTIPOLYGON (((25429061.671 6885924.826, 2543...              Virrat
# 303  MULTIPOLYGON (((25249457.595 6712380.553, 2524...               Vårdö
# 304  MULTIPOLYGON (((25337218.162 7044171.306, 2533...               Vöyri
# 305  MULTIPOLYGON (((25448851.344 7341757.573, 2544...           Ylitornio
# 306  MULTIPOLYGON (((25480930.575 7093492.130, 2548...           Ylivieska
# 307  MULTIPOLYGON (((25424728.065 6823819.477, 2542...            Ylöjärvi
# 308  MULTIPOLYGON (((25405949.862 6734532.930, 2540...               Ypäjä
# 309  MULTIPOLYGON (((25448901.457 6917813.027, 2545...              Ähtäri
# 310  MULTIPOLYGON (((25536840.247 6930679.152, 2553...           Äänekoski
#
#       pop18  employment17
# 0     16611          71.9
# 1      9700          67.7
# 2      2573          71.5
# 3     11544          69.5
# 4      8149          69.1
# 5      4958          77.9
# 6      3984          78.0
# 7       449          80.8
# 8       961          82.0
# 9      1405          65.6
# 10     1852          64.0
# 11   283632          74.2
# 12    11748          75.7
# 13     9454          76.3
# 14     2473          74.9
# 15     2588          83.2
# 16    17028          66.9
# 17      534          85.0
# 18      514          79.4
# 19     7147          68.4
# 20     6854          68.3
# 21      974          72.2
# 22     1165          75.7
# 23    20286          67.2
# 24     1577          83.4
# 25     4939          65.9
# 26     8379          71.1
# 27     7018          68.0
# 28     2780          67.0
# 29     9475          76.2
# 30     8417          74.7
# 31    18889          66.1
# 32     3329          62.3
# 33   648042          71.7
# 34     2152          61.8
# 35    23602          74.2
# 36     1666          69.1
# 37    10091          72.2
# 38     2235          70.9
# 39     2287          59.5
# 40    46504          73.1
# 41    10510          72.2
# 42    67532          70.4
# 43     9862          68.1
# 44    21472          68.3
# 45     6765          70.4
# 46     7003          67.1
# 47    12187          75.7
# 48     4973          59.6
# 49    26932          64.3
# 50     6930          71.4
# 51     5403          78.4
# 52     1976          73.7
# 53     4601          72.7
# 54    16447          73.6
# 55    76551          62.6
# 56     5195          74.0
# 57     5032          87.2
# 58     4812          68.5
# 59     4467          67.6
# 60     4709          58.2
# 61     1884          71.5
# 62     6225          70.0
# 63   141305          65.8
# 64     1809          71.6
# 65    20607          66.9
# 66    43410          75.3
# 67    33458          76.9
# 68     2990          57.0
# 69    36973          66.5
# 70    12387          73.6
# 71    31676          76.2
# 72     5452          67.0
# 73    11471          67.9
# 74     1353          63.5
# 75     5502          71.3
# 76     1274          73.9
# 77     8778          71.4
# 78     4031          64.6
# 79     2390          67.5
# 80     1262          68.9
# 81    13375          68.8
# 82    16022          73.4
# 83     9615          76.7
# 84     4273          79.4
# 85     2244          67.0
# 86    21021          59.5
# 87     7370          62.8
# 88     8147          71.1
# 89     6724          70.6
# 90    17923          75.3
# 91    36254          74.1
# 92     9762          65.3
# 93     1910          67.8
# 94     1615          59.2
# 95    39262          76.7
# 96    10358          61.4
# 97     6436          77.1
# 98     8153          66.8
# 99     1103          63.0
# 100    7226          67.8
# 101   47657          72.5
# 102    3834          71.1
# 103    2698          68.6
# 104   14849          74.0
# 105    2122          77.8
# 106    2340          75.5
# 107   52883          62.7
# 108   83177          66.9
# 109    6596          75.0
# 110    6509          80.3
# 111    8329          61.9
# 112    2238          66.1
# 113     315          77.5
# 114  118664          67.5
# 115    3572          74.2
# 116   20952          71.3
# 117     926          68.7
# 118   15207          66.9
# 119    1343          66.1
# 120    4451          70.8
# 121    2613          67.4
# 122     236          82.8
# 123  119951          66.5
# 124    8058          77.4
# 125    8647          77.8
# 126    2665          73.1
# 127    9617          67.9
# 128    3078          67.6
# 129   72699          66.2
# 130   14427          72.7
# 131   18927          73.3
# 132    3043          71.9
# 133    2033          85.2
# 134   23206          76.2
# 135    9650          68.8
# 136     737          65.7
# 137   11098          57.6
# 138   19831          80.0
# 139   10161          77.1
# 140   12145          71.2
# 141   46296          73.2
# 142   16032          71.0
# 143    7861          75.8
# 144   14891          71.2
# 145     707          68.1
# 146    2052          71.2
# 147     382          86.7
# 148    5340          83.8
# 149    4662          70.8
# 150    5477          78.9
# 151   11743          80.6
# 152    2018          73.5
# 153    9554          81.0
# 154    1104          67.4
# 155    3115          66.4
# 156    1940          64.6
# 157   53818          68.5
# 158    8980          69.7
# 159    1584          66.0
# 160    2299          74.2
# 161   19444          81.8
# 162   10170          76.6
# 163    7766          74.9
# 164    1922          72.9
# 165   20686          77.6
# 166    9983          65.8
# 167    5924          67.0
# 168   19245          74.8
# 169    5437          69.9
# 170   10737          71.3
# 171   33527          73.7
# 172    4733          79.6
# 173    7641          64.6
# 174   42665          79.5
# 175    9471          81.6
# 176   16091          72.1
# 177    1364          73.5
# 178    9221          69.5
# 179    7430          70.4
# 180  203567          66.3
# 181    6803          58.4
# 182    2963          66.8
# 183   10832          76.9
# 184    3336          59.9
# 185   15217          76.1
# 186    4842          65.9
# 187    6469          67.2
# 188   11016          82.7
# 189     954          64.2
# 190    3438          62.4
# 191    2825          69.5
# 192    1713          66.9
# 193    3900          72.1
# 194   17933          65.3
# 195    4498          64.7
# 196   19278          73.5
# 197    4053          67.7
# 198   19368          78.1
# 199    4307          63.0
# 200    2146          68.2
# 201   84403          67.8
# 202    5068          80.7
# 203   50262          75.3
# 204    3237          59.4
# 205    7990          60.4
# 206    1899          74.6
# 207    2896          70.0
# 208    2597          56.1
# 209    2197          67.3
# 210    5187          72.3
# 211    3146          70.3
# 212    5248          62.6
# 213    1557          69.5
# 214    2028          75.7
# 215    6499          73.0
# 216    8333          75.6
# 217   24811          66.3
# 218   27592          72.3
# 219   24178          73.4
# 220    3514          65.8
# 221    3896          62.2
# 222   39360          71.8
# 223    3196          64.7
# 224    1651          57.5
# 225    3335          59.1
# 226    2743          70.4
# 227   28736          70.9
# 228    1288          66.7
# 229   62922          68.5
# 230    5099          68.2
# 231    4398          68.6
# 232    6251          81.1
# 233    2181          56.6
# 234    9415          62.6
# 235    3491          61.2
# 236   52321          67.6
# 237    1858          84.8
# 238   24651          70.0
# 239    2994          76.1
# 240    3429          71.3
# 241   33611          65.1
# 242    1015          64.9
# 243   63288          73.0
# 244    4980          70.0
# 245    1458          63.4
# 246    5249          68.3
# 247    5301          67.5
# 248   21674          75.7
# 249    3045          65.5
# 250   20666          81.0
# 251    6134          78.6
# 252    8444          70.6
# 253    2085          68.7
# 254    8828          70.9
# 255    3967          63.6
# 256   10389          71.6
# 257      91          78.8
# 258    2530          64.2
# 259    1028          84.9
# 260    7862          59.4
# 261    7145          66.6
# 262    3753          64.8
# 263    6811          75.4
# 264    4715          73.6
# 265    4024          63.2
# 266    1662          75.5
# 267    6081          74.6
# 268  235239          66.5
# 269    1567          64.5
# 270    3062          63.9
# 271    5158          69.3
# 272    4482          60.8
# 273    3112          71.6
# 274    2406          74.4
# 275   21875          67.9
# 276  191331          66.3
# 277    2551          59.7
# 278   38664          78.8
# 279    6758          73.3
# 280   13021          73.6
# 281    4792          68.0
# 282    2702          64.0
# 283    1232          70.4
# 284    3783          72.1
# 285    7455          81.1
# 286   15700          76.8
# 287    2869          61.2
# 288   67552          70.2
# 289   21137          69.5
# 290    2143          61.7
# 291  228166          74.2
# 292   20829          62.3
# 293    2285          76.2
# 294    2058          65.5
# 295    4393          76.7
# 296    3166          74.2
# 297    3676          72.4
# 298   29211          76.8
# 299    6264          64.3
# 300    2901          69.0
# 301    3150          66.4
# 302    6739          67.3
# 303     448          86.8
# 304    6613          78.7
# 305    4022          65.5
# 306   15212          70.9
# 307   32983          76.6
# 308    2357          71.2
# 309    5703          68.9
# 310   18851          65.2

# %%
# Set the data frame display back to 5 first, 5 last rows.

pd.set_option('display.max_rows', 10)

# Delete the unnecessary column "nimi_caller" and rename "nimi_oher"

geodata = geodata[["geometry", "nimi_other", "pop18", "employment17"]]

geodata = geodata.rename(columns={"nimi_other": "nimi"})

# %% [markdown]
# Okey, everything looks as it should be. Now, let's visualize the data!
#
# I think that I could classify the population and employment columns and try to somehow visualize them together.
#
# I could try to see if those two are related somehow.
#
# Actually, I'll first see if there's correlation between them.

# %%
# Pearson correlation
from scipy import stats

stats.pearsonr(geodata["pop18"], geodata["employment17"])
# Out:
# (-0.006017851842099295, 0.9158207073900534)

# %%
plt.scatter(geodata["pop18"], geodata["employment17"])

# %% [markdown]
# Correlation seems to be nonexistent (-0.006) wich is most likely caused by the distribution of population: most of the municipalities seem to have some thousands of residents, with some "outliers" having around 100000-300000 residents and one (Helsinki) over 600000.
#
# Let's decide the classifying method to use when plotting the data. Employment data seems to be somewhat normally distributed, so e.g. equal intervals could work for it; however, population data is heavily skewed to the left (towards smaller values).
#
# Let's take a closer look to the population data to decide the classifying method for it since the values are so clumped in the scatter plot that it is impossible to make any inferences. I'll use the same classification method for both datasets, defining it according to population.

# %%
from numpy import mean, median

print("Minimum: ", min(geodata["pop18"]))
print("Maximum: ", max(geodata["pop18"]))
print("Mean: ", round(mean(geodata["pop18"]), 0))
print("Median: ", round(median(geodata["pop18"]), 0))
# Out:
# Minimum:  91
# Maximum:  648042
# Mean:  17743.0
# Median:  6081.0

# %% [markdown]
# I'll use natural breaks as the classification scheme with nine classes for both datasets.
#
# I'll also bring one more data set to this exercise, namely region centers (maakuntakeskukset) to visualize how the inhabitants and employment relate to them. I put the file together myself, using the corresponding townhouse address as the address for each city.

# %%
from geopandas.tools import geocode
from shapely.geometry import Point, Polygon, MultiPolygon

# Read the data

mkkeskus = pd.read_csv('data/mkkeskukset.txt', sep=';')

# Geocode the addresses using Nominatim

geokeskus = geocode(mkkeskus["osoite"], provider="nominatim", user_agent='autogis_SP', timeout=3)

geokeskus.head()
# Out:
#                     geometry  \
# 0  POINT (24.95287 60.16825)
# 1  POINT (22.26864 60.44879)
# 2  POINT (21.79485 61.48898)
# 3  POINT (24.46689 60.99599)
# 4  POINT (23.76044 61.49599)
#
#                                              address
# 0  Helsingin kaupungintalo, 11-13, Pohjoisesplana...
# 1  Turun kaupungintalo, 2, Aurakatu, Aninkaistenm...
# 2  Porin Kaupungintalo, 12, Hallituskatu, Kirjuri...
# 3  Silmälääkäri Miikael Heiskanen, 16, Palokunnan...
# 4  Aleksis Kiven katu, Tammerkoski, Ratina, Tampe...

# %%
# Let's add the columns that went lost in translation: 

geokeskus["maakunta"] = mkkeskus["maakunta"]
geokeskus["kaupunki"] = mkkeskus["kaupunki"]

geokeskus.head()
# Out:
#                     geometry  \
# 0  POINT (24.95287 60.16825)
# 1  POINT (22.26864 60.44879)
# 2  POINT (21.79485 61.48898)
# 3  POINT (24.46689 60.99599)
# 4  POINT (23.76044 61.49599)
#
#                                              address         maakunta  \
# 0  Helsingin kaupungintalo, 11-13, Pohjoisesplana...          Uusimaa
# 1  Turun kaupungintalo, 2, Aurakatu, Aninkaistenm...  Varsinais-Suomi
# 2  Porin Kaupungintalo, 12, Hallituskatu, Kirjuri...        Satakunta
# 3  Silmälääkäri Miikael Heiskanen, 16, Palokunnan...  Häme, Kantahäme
# 4  Aleksis Kiven katu, Tammerkoski, Ratina, Tampe...        Pirkanmaa
#
#       kaupunki
# 0     Helsinki
# 1        Turku
# 2         Pori
# 3  Hämeenlinna
# 4      Tampere

# %%
# Convert the crs and check the result

geokeskus = geokeskus.to_crs(geodata.crs)

print(geokeskus.crs)
# Out:
# EPSG:3879

# %%
# Define output filename for the figure in here and use it when saving the file
output_fig = "static_map.png"

# Plot the data into two subplots with 1 row and 2 columns.

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,10))

geodata.plot(ax=axes[0],
             column="employment17",
             scheme="NaturalBreaks",
             k=9,
             cmap="autumn_r",
             legend=True
             );
axes[0].set_title("Employment, %")

geodata.plot(ax=axes[1],
             column="pop18",
             scheme="NaturalBreaks",
             k=9,
             cmap="autumn_r",
             legend=True
             );
axes[1].set_title("Population, inhabitants")

geokeskus.plot(ax=axes[0], 
               color="black",
              );

geokeskus.plot(ax=axes[1], 
               color="black",
               );

# Re-position the legends and set a title

axes[0].get_legend().set_bbox_to_anchor((1.4, 1.01))
axes[0].get_legend().set_title("Employment-%")

axes[1].get_legend().set_bbox_to_anchor((1.56, 1.01))
axes[1].get_legend().set_title("Inhabitants")

# Save the image to file

plt.savefig(output_fig)

# %% [markdown]
# As one would expect, employment rates and population numbers are higher closer to the region centers. Lapland seems to be an exception regarding employment, this could be caused for example because of tourism-related jobs that can be located further away from Rovaniemi and other towns in the area. Interestingly, the number of inhabitants and employment rate don't seem to be very highly related. There are some indications of a correlation between those two, but the relationship is much weaker than I expected.

# %% [markdown]
# Since the maps above are quite basic and didn't really involve much processing, I decided to do better ones:
#
# I will define dominance areas for each region center city by calculating centroid for each municipality polygon and then finding the nearest city for each of them. This approach has its limitations since it doesn't account for travel times, roads, etc., but it could perhaps be developed further by adding other datas sets.

# %%
# Calculate centroid for each municipality and save it to a new column named "centroid"

geodata["centroid"] = None

for index, row in geodata.iterrows():
    poly = row.geometry
    centr = poly.centroid
    geodata.loc[index, "centroid"] = centr

# %%
geodata.head()
# Out:
#                                             geometry       nimi  pop18  \
# 0  MULTIPOLYGON (((25432855.364 6772522.137, 2543...       Akaa  16611
# 1  MULTIPOLYGON (((25449483.076 6958686.809, 2545...   Alajärvi   9700
# 2  MULTIPOLYGON (((25468062.983 7104646.044, 2546...  Alavieska   2573
# 3  MULTIPOLYGON (((25423291.995 6918828.726, 2542...     Alavus  11544
# 4  MULTIPOLYGON (((25542265.535 6776476.194, 2554...   Asikkala   8149
#
#    employment17                                     centroid
# 0          71.9   POINT (25432548.47977924 6783254.51208106)
# 1          67.7  POINT (25444611.01079298 6985508.925852679)
# 2          71.5  POINT (25467511.61630115 7120187.997117932)
# 3          69.5  POINT (25427913.73972826 6942440.066593251)
# 4          69.1  POINT (25531525.14987801 6789205.303534576)

# %%
# Create a unary union of the cities in geokeskus

geounion = geokeskus["geometry"].unary_union

# Create a new column named "nearest_city" and calculate the nearest city for each municipality

geodata["nearest_city"] = None

for index, row in geodata.iterrows():
    point = row.centroid
    multipoint = geounion
    queried_geom, nearest_geom = nearest_points(point, multipoint)
    geodata.loc[index, "nearest_city"] = nearest_geom

# %%
geodata.head()
# Out:
#                                             geometry       nimi  pop18  \
# 0  MULTIPOLYGON (((25432855.364 6772522.137, 2543...       Akaa  16611
# 1  MULTIPOLYGON (((25449483.076 6958686.809, 2545...   Alajärvi   9700
# 2  MULTIPOLYGON (((25468062.983 7104646.044, 2546...  Alavieska   2573
# 3  MULTIPOLYGON (((25423291.995 6918828.726, 2542...     Alavus  11544
# 4  MULTIPOLYGON (((25542265.535 6776476.194, 2554...   Asikkala   8149
#
#    employment17                                     centroid  \
# 0          71.9   POINT (25432548.47977924 6783254.51208106)
# 1          67.7  POINT (25444611.01079298 6985508.925852679)
# 2          71.5  POINT (25467511.61630115 7120187.997117932)
# 3          69.5  POINT (25427913.73972826 6942440.066593251)
# 4          69.1  POINT (25531525.14987801 6789205.303534576)
#
#                                   nearest_city
# 0  POINT (25433981.73634464 6821390.614003492)
# 1  POINT (25389867.58878904 6966457.940480988)
# 2  POINT (25408207.24117174 7083296.255874128)
# 3  POINT (25389867.58878904 6966457.940480988)
# 4  POINT (25535496.83015619 6763471.229930341)

# %%
# Get the names for nearest cities

for index, row in geodata.iterrows():
    tempname = str(geokeskus.loc[geokeskus["geometry"] == row.nearest_city, ["kaupunki"]].values[0])
    expendable1, name, expendable2 = tempname.split("'")
    geodata.loc[index, "nearest_name"] = name

# %%
geodata.head()
# Out:
#                                             geometry       nimi  pop18  \
# 0  MULTIPOLYGON (((25432855.364 6772522.137, 2543...       Akaa  16611
# 1  MULTIPOLYGON (((25449483.076 6958686.809, 2545...   Alajärvi   9700
# 2  MULTIPOLYGON (((25468062.983 7104646.044, 2546...  Alavieska   2573
# 3  MULTIPOLYGON (((25423291.995 6918828.726, 2542...     Alavus  11544
# 4  MULTIPOLYGON (((25542265.535 6776476.194, 2554...   Asikkala   8149
#
#    employment17                                     centroid  \
# 0          71.9   POINT (25432548.47977924 6783254.51208106)
# 1          67.7  POINT (25444611.01079298 6985508.925852679)
# 2          71.5  POINT (25467511.61630115 7120187.997117932)
# 3          69.5  POINT (25427913.73972826 6942440.066593251)
# 4          69.1  POINT (25531525.14987801 6789205.303534576)
#
#                                   nearest_city nearest_name
# 0  POINT (25433981.73634464 6821390.614003492)      Tampere
# 1  POINT (25389867.58878904 6966457.940480988)    Seinäjoki
# 2  POINT (25408207.24117174 7083296.255874128)      Kokkola
# 3  POINT (25389867.58878904 6966457.940480988)    Seinäjoki
# 4  POINT (25535496.83015619 6763471.229930341)        Lahti

# %%
# Group geodata by nearest city

grouped = geodata.groupby(by="nearest_name")

grouped1 = geodata.groupby(by="nearest_name")["pop18"].sum().reset_index() 

grouped2 = geodata.groupby(by="nearest_name")["employment17"].mean().round(0).reset_index() 

groupeddata = grouped1.merge(grouped2, on="nearest_name", how="left")

assert len(grouped3.groups) == geodata["nearest_name"].nunique(), "Number of groups should match number of unique cities!"

grouped.head()
# Out:
#                                               geometry        nimi  pop18  \
# 0    MULTIPOLYGON (((25432855.364 6772522.137, 2543...        Akaa  16611
# 1    MULTIPOLYGON (((25449483.076 6958686.809, 2545...    Alajärvi   9700
# 2    MULTIPOLYGON (((25468062.983 7104646.044, 2546...   Alavieska   2573
# 3    MULTIPOLYGON (((25423291.995 6918828.726, 2542...      Alavus  11544
# 4    MULTIPOLYGON (((25542265.535 6776476.194, 2554...    Asikkala   8149
# ..                                                 ...         ...    ...
# 149  MULTIPOLYGON (((25647756.306 6745743.225, 2564...     Luumäki   4662
# 150  MULTIPOLYGON (((25284786.867 7008884.970, 2528...    Maalahti   5477
# 157  MULTIPOLYGON (((25627190.722 6791080.232, 2562...     Mikkeli  53818
# 161  MULTIPOLYGON (((25304458.798 7042830.221, 2530...  Mustasaari  19444
# 186  MULTIPOLYGON (((25737125.498 6820876.067, 2573...   Parikkala   4842
#
#      employment17                                     centroid  \
# 0            71.9   POINT (25432548.47977924 6783254.51208106)
# 1            67.7  POINT (25444611.01079298 6985508.925852679)
# 2            71.5  POINT (25467511.61630115 7120187.997117932)
# 3            69.5  POINT (25427913.73972826 6942440.066593251)
# 4            69.1  POINT (25531525.14987801 6789205.303534576)
# ..            ...                                          ...
# 149          70.8  POINT (25637040.78814895 6761441.971212647)
# 150          78.9  POINT (25322268.96358317 6979248.537929744)
# 157          68.5  POINT (25622218.74397387 6842900.903712555)
# 161          81.8  POINT (25330345.89206031 7011513.076120408)
# 186          65.9  POINT (25745396.31746197 6845314.401570727)
#
#                                     nearest_city  nearest_name
# 0    POINT (25433981.73634464 6821390.614003492)       Tampere
# 1    POINT (25389867.58878904 6966457.940480988)     Seinäjoki
# 2    POINT (25408207.24117174 7083296.255874128)       Kokkola
# 3    POINT (25389867.58878904 6966457.940480988)     Seinäjoki
# 4    POINT (25535496.83015619 6763471.229930341)         Lahti
# ..                                           ...           ...
# 149   POINT (25672502.23261303 6776148.44072575)  Lappeenranta
# 150   POINT (25328906.27566722 7003481.46330949)         Vaasa
# 157  POINT (25620308.92203796 6844102.862906922)       Mikkeli
# 161   POINT (25328906.27566722 7003481.46330949)         Vaasa
# 186   POINT (25672502.23261303 6776148.44072575)  Lappeenranta
#
# [95 rows x 7 columns]

# %%
groupeddata
# Out:
#    nearest_name    pop18  employment17
# 0      Helsinki  1532750          77.0
# 1   Hämeenlinna   260753          72.0
# 2       Joensuu   190801          63.0
# 3     Jyväskylä   281707          68.0
# 4       Kajaani   110928          64.0
# ..          ...      ...           ...
# 14    Rovaniemi   172708          67.0
# 15    Seinäjoki   202249          70.0
# 16      Tampere   468827          72.0
# 17        Turku   506503          75.0
# 18        Vaasa   119999          77.0
#
# [19 rows x 3 columns]

# %%
grouped.groups.keys()
# Out:
# dict_keys(['Helsinki', 'Hämeenlinna', 'Joensuu', 'Jyväskylä', 'Kajaani', 'Kokkola', 'Kotka', 'Kuopio', 'Lahti', 'Lappeenranta', 'Maarianhamina', 'Mikkeli', 'Oulu', 'Pori', 'Rovaniemi', 'Seinäjoki', 'Tampere', 'Turku', 'Vaasa'])

# %%
# Define output filename for the figure in here and use it when saving the file
output_fig2 = "static_map_final.png"

# I couldn't figure out how to plot the dominance areas of region center cities inside a loop (mainly the color would've been a problem), so here's my extremely inefficient approach:

figure, axs = plt.subplots(nrows=1, ncols=3, figsize=(25,10))

grouped.get_group("Helsinki").plot(ax=axs[0],
                                   color="grey"
                                  );

grouped.get_group("Hämeenlinna").plot(ax=axs[0],
                                      color="powderblue"
                                     );

grouped.get_group("Joensuu").plot(ax=axs[0],
                                  color="deepskyblue"
                                 );

grouped.get_group("Jyväskylä").plot(ax=axs[0],
                                    color="silver"
                                   );

grouped.get_group("Kajaani").plot(ax=axs[0],
                                    color="cadetblue"
                                   );

grouped.get_group("Kokkola").plot(ax=axs[0],
                                    color="teal"
                                   );

grouped.get_group("Kotka").plot(ax=axs[0],
                                    color="aqua"
                                   );

grouped.get_group("Kuopio").plot(ax=axs[0],
                                    color="royalblue"
                                   );

grouped.get_group("Lahti").plot(ax=axs[0],
                                    color="turquoise"
                                   );

grouped.get_group("Lappeenranta").plot(ax=axs[0],
                                    color="slategray"
                                   );

grouped.get_group("Maarianhamina").plot(ax=axs[0],
                                    color="blue"
                                   );

grouped.get_group("Mikkeli").plot(ax=axs[0],
                                    color="aquamarine"
                                   );

grouped.get_group("Oulu").plot(ax=axs[0],
                                    color="darkcyan"
                                   );

grouped.get_group("Pori").plot(ax=axs[0],
                                    color="lightblue"
                                   );

grouped.get_group("Rovaniemi").plot(ax=axs[0],
                                    color="lightskyblue"
                                   );

grouped.get_group("Seinäjoki").plot(ax=axs[0],
                                    color="steelblue"
                                   );

grouped.get_group("Tampere").plot(ax=axs[0],
                                    color="cyan"
                                   );

grouped.get_group("Turku").plot(ax=axs[0],
                                    color="cornflowerblue"
                                   );

grouped.get_group("Vaasa").plot(ax=axs[0],
                                    color="darkslategrey"
                                   );

geokeskus.plot(ax=axs[0], 
               color="black",
               );

groupeddata.plot.bar(ax=axs[1],
                     x="nearest_name", 
                     y="pop18",
                     legend=True
                    );

groupeddata.plot.bar(ax=axs[2],
                     x="nearest_name", 
                     y="employment17",
                     legend=True
                    );

# Reposition the legend for population and employment data

axs[1].get_legend().set_title("Inhabitants per dominance area (millions)")
axs[2].get_legend().set_title("Employment rate per dominance area (%)")

# Create the legend for region center's dominance areas by hand, reposition the legend, and set a title
# Not much automation here unfortunately :DDD

import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

Hel_patch = mpatches.Patch(color="grey", label="Helsinki")
Ham_patch = mpatches.Patch(color="powderblue", label="Hämeenlinna")
Joe_patch = mpatches.Patch(color="deepskyblue", label="Joensuu")
Jyv_patch = mpatches.Patch(color="silver", label="Jyväskylä")
Kaj_patch = mpatches.Patch(color="cadetblue", label="Kajaani")
Kok_patch = mpatches.Patch(color="teal", label="Kokkola")
Kot_patch = mpatches.Patch(color="aqua", label="Kotka")
Kuo_patch = mpatches.Patch(color="royalblue", label="Kuopio")
Lah_patch = mpatches.Patch(color="turquoise", label="Lahti")
Lap_patch = mpatches.Patch(color="slategrey", label="Lappeenranta")
Mar_patch = mpatches.Patch(color="blue", label="Maarianhamina")
Mik_patch = mpatches.Patch(color="aquamarine", label="Mikkeli")
Oul_patch = mpatches.Patch(color="darkcyan", label="Oulu")
Por_patch = mpatches.Patch(color="lightblue", label="Pori")
Rov_patch = mpatches.Patch(color="lightskyblue", label="Rovaniemi")
Sei_patch = mpatches.Patch(color="steelblue", label="Seinäjoki")
Tam_patch = mpatches.Patch(color="cyan", label="Tampere")
Tur_patch = mpatches.Patch(color="cornflowerblue", label="Turku")
Vaa_patch = mpatches.Patch(color="darkslategrey", label="Vaasa")

axs[0].legend(handles=[Hel_patch, Ham_patch, Joe_patch, Jyv_patch, Kaj_patch, Kok_patch, Kot_patch, Kuo_patch, Lah_patch, Lap_patch, Mar_patch, Mik_patch, Oul_patch, Por_patch, Rov_patch, Sei_patch, Tam_patch, Tur_patch, Vaa_patch])

axs[0].get_legend().set_bbox_to_anchor((1.4, 1.01))
axs[0].get_legend().set_title("Dominant city")

plt.tight_layout()

# Save the image to file

plt.savefig(output_fig2)

# %% [markdown]
# So, above are three maps:
#
# 1. The dominance areas of region center cities (maakuntakeskukset). As I expected, they look quite a lot like current regions (maakunnat), but there are differences, too. The information could be combined with other data sets and be used to for example study, where do people travel to work from municipalities: do they cross current regions borders or not etc.
#
# 2. Population (million inhabitants) per dominance area.
#
# 3. Average employment rate per
